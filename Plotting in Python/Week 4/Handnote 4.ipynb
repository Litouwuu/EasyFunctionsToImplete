# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn-colorblind')

# %% [markdown]
# # DataFrame.plot

# %%
np.random.seed(123)
df = pd.DataFrame({'A':np.random.randn(365).cumsum(0),
                  'B':np.random.randn(365).cumsum(0)+20,
                  'C':np.random.randn(365).cumsum(0)-20},
                 index = pd.date_range('1/1/2021',periods=365))
df.head()
# Out:
#                    A          B          C
# 2021-01-01 -1.085631  20.059291 -20.230904
# 2021-01-02 -0.088285  21.803332 -16.659325
# 2021-01-03  0.194693  20.835588 -17.055481
# 2021-01-04 -1.311601  21.255156 -17.093802
# 2021-01-05 -1.890202  21.462083 -19.518638

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot('A','B',kind='scatter')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = df.plot.scatter('A','C',c=df['B'],s =df['B'],colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
np.random.seed(1234)

v1 = pd.Series(np.random.normal(0,10,1000), name = 'v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000),name='v2')

# %%
plt.figure()
plt.hist(v1,alpha=0.7,bins=np.arange(-50,150,5),label='v1')
plt.hist(v2,alpha=0.7,bins=np.arange(-50,150,5),label='v2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist([v1,v2],alpha = 0.5,histtype='barstacked',normed=True)
v3= np.concatenate((v1,v2))
sns.kdeplot(v3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure()
sns.distplot(v3,hist_kws={'color':'Teal'})
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(v1,v2,alpha=0.3)
# Out:
# <img src="data:image/png;base64,..." width="600">
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set_style('white')
sns.jointplot(v1,v2,kind='kde',space=0)
# Out:
# <img src="data:image/png;base64,..." width="600">
