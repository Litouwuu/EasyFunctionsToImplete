# %%
import pandas as pd
import numpy as np

# %%
Rawdata = pd.read_excel('COUNTOFD_BBCO_OFT_DATABASE.xlsx', header = 0)

# %%
InUse = ['SKUCode', 'ReleaseDate', 'ActualDeliveryDate','DeliveryOrderVolumeHL']
df = Rawdata[InUse]
df
# Out:
#         SKUCode ReleaseDate ActualDeliveryDate  DeliveryOrderVolumeHL
# 0         62808  2021-04-23         2021-05-03                  3.200
# 1         78561  2021-05-20         2021-05-22                124.800
# 2         86774  2021-05-20         2021-05-22                 22.176
# 3         78561  2021-05-20         2021-05-22                115.200
# 4         78561  2021-05-20         2021-05-22                 43.200
# 5         78561  2021-05-20         2021-05-22                 14.400
# 6         78561  2021-05-20         2021-05-22                 19.200
# 7         74155  2021-05-08         2021-05-10                 27.720
# 8         76353  2021-05-08         2021-05-10                  3.696
# 9         76353  2021-05-08         2021-05-10                  4.026
# 10        76353  2021-05-08         2021-05-10                  4.290
# 11        71502  2021-05-08         2021-05-10                  6.804
# ...

# %%
group = df.groupby(['SKUCode','ReleaseDate'])['DeliveryOrderVolumeHL'].sum()

# %%
group
# Out:
# SKUCode  ReleaseDate
# 44946    2021-01-06       6.653
#          2021-01-11       6.653
#          2021-01-29      17.107
#          2021-03-15      32.947
#          2021-03-17      19.958
#          2021-04-20      17.107
#          2021-06-25       2.851
# 44947    2021-01-06       6.732
#          2021-01-19       1.347
#          2021-01-26       0.237
#          2021-01-28       0.792
#          2021-01-29      39.917
#          2021-02-02       0.079
#          2021-02-23       5.544
#          2021-02-24      11.088
#          2021-03-02       0.079
#          2021-03-03       0.633
#          2021-03-09       0.079
#          2021-03-10       0.475
#          2021-03-15     127.353
#          2021-03-19       3.960
#          2021-03-30       0.158
#          2021-03-31       4.039
#          2021-04-01       6.653
#          2021-04-02       0.079
#          2021-04-07       0.158
#          2021-04-09       0.158
#          2021-04-16       0.238
# ...
